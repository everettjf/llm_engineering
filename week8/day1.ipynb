# %% [markdown]
# # Welcome to a very busy Week 8 folder
#
# ## We have lots to do this week!
#
# We'll move at a faster pace than usual, particularly as you're becoming proficient LLM engineers.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Especially important this week: pull the latest</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a <a href="https://chatgpt.com/share/6734e705-3270-8012-a074-421661af6ba9">git pull and merge your changes as needed</a>. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/><br/>
#             After you've pulled the code, from the llm_engineering directory, in an Anaconda prompt (PC) or Terminal (Mac), run:<br/>
#             <code>conda env update --f environment.yml --prune</code><br/>
#             Or if you used virtualenv rather than Anaconda, then run this from your activated environment in a Powershell (PC) or Terminal (Mac):<br/>
#             <code>pip install -r requirements.txt</code>
#             <br/>Then restart the kernel (Kernel menu >> Restart Kernel and Clear Outputs Of All Cells) to pick up the changes.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Just one import to start with!!

import modal

# %% [markdown]
# # Setting up the modal tokens
#
# The first time you run this, please uncomment the next line and execute it.
# This is the same as running `modal setup` from the command line. It connects with Modal and installs your tokens.
#
# A student on Windows mentioned that on Windows, you might also need to run this command from a command prompt afterwards:
# `modal token new`
# (Thank you Ed B. for that!)
#
# And I've also heard that in some situations, you might need to restart the Kernel of this jupyter notebook after running this. (Kernel menu >> Restart Kernel and Clear Outputs of All Cells).

# %%
# Remove the '# ' from the next line and run the cell
# !modal setup

# %%
from hello import app, hello

# %%
with app.run():
    reply=hello.local()
reply
# Out:
# 'Hello from Cupertino, California, US!! (AS7922 Comcast Cable Communications, LLC) (America/Los_Angeles)'

# %%
with app.run():
    reply=hello.remote()
reply
# Out:
# 'Hello from Ashburn, Virginia, US!! (AS31898 Oracle Corporation) (America/New_York)'

# %% [markdown]
# # Before we move on -
#
# ## We need to set your HuggingFace Token as a secret in Modal
#
# 1. Go to modal.com, sign in and go to your dashboard
# 2. Click on Secrets in the nav bar
# 3. Create new secret, click on Hugging Face, this new secret needs to be called **hf-secret** because that's how we refer to it in the code
# 4. Fill in your HF_TOKEN where it prompts you
#
# ### And now back to business: time to work with Llama

# %%
from llama import app, generate

# %%
with modal.enable_output():
    with app.run():
        result=generate.remote("Life is a mystery, everyone must stand alone, I hear")
result
# Out:
# Output()
# ✓ Initialized. View run at https://modal.com/apps/evilret/main/ap-AeWY5wl0TIdClFKywjW20W
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# Building image im-pH9xJTztiubTVOHvLphvtl
# => Step 0: FROM base
# => Step 1: RUN python -m pip install accelerate bitsandbytes torch transformers
# Looking in indexes: http://pypi-mirror.modal.local:5555/simple
# Collecting accelerate
#   Downloading http://pypi-mirror.modal.local:5555/simple/accelerate/accelerate-1.2.1-py3-none-any.whl.metadata (19 kB)
# Collecting bitsandbytes
#   Downloading http://pypi-mirror.modal.local:5555/simple/bitsandbytes/bitsandbytes-0.45.0-py3-none-manylinux_2_24_x86_64.whl.metadata (2.9 kB)
# Collecting torch
#   Downloading http://pypi-mirror.modal.local:5555/simple/torch/torch-2.5.1-cp311-cp311-manylinux1_x86_64.whl.metadata (28 kB)
# Collecting transformers
#   Downloading http://pypi-mirror.modal.local:5555/simple/transformers/transformers-4.47.0-py3-none-any.whl.metadata (43 kB)
# Collecting numpy<3.0.0,>=1.17 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/numpy/numpy-2.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting packaging>=20.0 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/packaging/packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting psutil (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/psutil/psutil-6.1.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting pyyaml (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/pyyaml/PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting huggingface-hub>=0.21.0 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/huggingface-hub/huggingface_hub-0.27.0-py3-none-any.whl.metadata (13 kB)
# Collecting safetensors>=0.4.3 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/safetensors/safetensors-0.4.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: typing_extensions>=4.8.0 in /usr/local/lib/python3.11/site-packages (from bitsandbytes) (4.12.2)
# Collecting filelock (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/filelock/filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting networkx (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/networkx/networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/jinja2/jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting fsspec (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/fsspec/fsspec-2024.10.0-py3-none-any.whl.metadata (11 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-nvrtc-cu12/nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-runtime-cu12/nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-cupti-cu12/nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cublas-cu12/nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufft-cu12/nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-curand-cu12/nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusolver-cu12/nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparse-cu12/nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nccl-cu12/nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvtx-cu12/nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvjitlink-cu12/nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.1.0 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/triton/triton-3.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# Collecting sympy==1.13.1 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/sympy/sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/mpmath/mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting regex!=2019.12.17 (from transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/regex/regex-2024.11.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
# Collecting requests (from transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/requests/requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting tokenizers<0.22,>=0.21 (from transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/tokenizers/tokenizers-0.21.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting tqdm>=4.27 (from transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/tqdm/tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/markupsafe/MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting charset-normalizer<4,>=2 (from requests->transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/charset-normalizer/charset_normalizer-3.4.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (34 kB)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/site-packages (from requests->transformers) (3.10)
# Collecting urllib3<3,>=1.21.1 (from requests->transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/urllib3/urllib3-2.2.3-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/site-packages (from requests->transformers) (2024.8.30)
# Downloading http://pypi-mirror.modal.local:5555/simple/accelerate/accelerate-1.2.1-py3-none-any.whl (336 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/bitsandbytes/bitsandbytes-0.45.0-py3-none-manylinux_2_24_x86_64.whl (69.1 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 MB 412.1 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/torch/torch-2.5.1-cp311-cp311-manylinux1_x86_64.whl (906.5 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.5/906.5 MB 459.2 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cublas-cu12/nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 290.7 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-cupti-cu12/nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 141.8 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-nvrtc-cu12/nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 251.3 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-runtime-cu12/nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 82.1 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 456.7 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufft-cu12/nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 218.9 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-curand-cu12/nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 320.0 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusolver-cu12/nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 412.9 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparse-cu12/nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 451.2 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nccl-cu12/nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 484.0 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvjitlink-cu12/nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 562.4 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvtx-cu12/nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/sympy/sympy-1.13.1-py3-none-any.whl (6.2 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 542.2 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/triton/triton-3.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (209.5 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 490.7 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/transformers/transformers-4.47.0-py3-none-any.whl (10.1 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 473.5 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/huggingface-hub/huggingface_hub-0.27.0-py3-none-any.whl (450 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/fsspec/fsspec-2024.10.0-py3-none-any.whl (179 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/numpy/numpy-2.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 623.3 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/packaging/packaging-24.2-py3-none-any.whl (65 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/pyyaml/PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (762 kB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 763.0/763.0 kB 906.4 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/regex/regex-2024.11.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (792 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 792.7/792.7 kB 633.8 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/safetensors/safetensors-0.4.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (435 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/tqdm/tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/filelock/filelock-3.16.1-py3-none-any.whl (16 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/jinja2/jinja2-3.1.4-py3-none-any.whl (133 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/networkx/networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 758.8 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/psutil/psutil-6.1.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (287 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/requests/requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/charset-normalizer/charset_normalizer-3.4.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/markupsafe/MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/mpmath/mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 695.3 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/urllib3/urllib3-2.2.3-py3-none-any.whl (126 kB)
# Installing collected packages: mpmath, urllib3, tqdm, sympy, safetensors, regex, pyyaml, psutil, packaging, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, MarkupSafe, fsspec, filelock, charset-normalizer, triton, requests, nvidia-cusparse-cu12, nvidia-cudnn-cu12, jinja2, nvidia-cusolver-cu12, huggingface-hub, torch, tokenizers, transformers, bitsandbytes, accelerate
# Successfully installed MarkupSafe-3.0.2 accelerate-1.2.1 bitsandbytes-0.45.0 charset-normalizer-3.4.0 filelock-3.16.1 fsspec-2024.10.0 huggingface-hub-0.27.0 jinja2-3.1.4 mpmath-1.3.0 networkx-3.4.2 numpy-2.2.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.4.127 packaging-24.2 psutil-6.1.0 pyyaml-6.0.2 regex-2024.11.6 requests-2.32.3 safetensors-0.4.5 sympy-1.13.1 tokenizers-0.21.0 torch-2.5.1 tqdm-4.67.1 transformers-4.47.0 triton-3.1.0 urllib3-2.2.3
# Saving image...
# Image saved, took 2.88s
# Built image im-pH9xJTztiubTVOHvLphvtl in 70.18s
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ✓ Created objects.
# ├── 🔨 Created mount /Users/eevv/focus/llm_engineering/week8/llama.py
# ├── 🔨 Created mount PythonPackage:hello
# └── 🔨 Created function generate.
# Output()
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Downloading shards:  25%|██▌       | 1/4 [07:58<23:54, 478.30s/it]
# Downloading shards:  50%|█████     | 2/4 [15:58<15:59, 479.53s/it]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Downloading shards:  75%|███████▌  | 3/4 [23:51<07:56, 476.37s/it]
# [Thread-5 (thread_inner)] 2024-12-16T22:57:23-0800 Loop attempt for _run_app.<locals>.heartbeat failed
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/llms/lib/python3.11/site-packages/modal/_utils/async_utils.py", line 195, in loop_coro
#     await asyncio.wait_for(async_f(), timeout=timeout)
#   File "/opt/anaconda3/envs/llms/lib/python3.11/asyncio/tasks.py", line 489, in wait_for
#     return fut.result()
#            ^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/llms/lib/python3.11/site-packages/modal/runner.py", line 56, in _heartbeat
#     await retry_transient_errors(client.stub.AppHeartbeat, request, attempt_timeout=HEARTBEAT_TIMEOUT)
#   File "/opt/anaconda3/envs/llms/lib/python3.11/site-packages/modal/_utils/grpc_utils.py", line 184, in retry_transient_errors
#     raise exc
#   File "/opt/anaconda3/envs/llms/lib/python3.11/site-packages/modal/_utils/grpc_utils.py", line 178, in retry_transient_errors
#     return await fn(*args, metadata=metadata, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/llms/lib/python3.11/site-packages/modal/client.py", line 396, in __call__
#     return await self.client._call_unary(self._wrapped_method_name, req, timeout=timeout, metadata=metadata)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/llms/lib/python3.11/site-packages/modal/client.py", line 338, in _call_unary
#     return await self._call_safely(coro, grpclib_method.name)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/llms/lib/python3.11/site-packages/modal/client.py", line 296, in _call_safely
#     return await request_task
#            ^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/llms/lib/python3.11/site-packages/grpclib/client.py", line 904, in __call__
#     reply = await stream.recv_message()
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/llms/lib/python3.11/site-packages/grpclib/client.py", line 425, in recv_message
#     await self.recv_initial_metadata()
#   File "/opt/anaconda3/envs/llms/lib/python3.11/site-packages/grpclib/client.py", line 393, in recv_initial_metadata
#     self._raise_for_grpc_status(status, message, details)
#   File "/opt/anaconda3/envs/llms/lib/python3.11/site-packages/grpclib/client.py", line 345, in _raise_for_grpc_status
#     raise GRPCError(status, message, details)
# grpclib.exceptions.GRPCError: (<Status.FAILED_PRECONDITION: 9>, 'App state is APP_STATE_STOPPED', None)
# Downloading shards: 100%|██████████| 4/4 [25:43<00:00, 332.66s/it]Downloading shards: 100%|██████████| 4/4 [25:43<00:00, 385.91s/it]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:07<00:22,  7.47s/it]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:15<00:15,  7.58s/it]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:21<00:07,  7.16s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:23<00:00,  5.04s/it]Loading checkpoint shards: 100%|██████████| 4/4 [00:23<00:00,  5.90s/it]
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Stopping app - local client disconnected. Use `modal run --detach` to keep apps running even if your local client disconnects.
# ✓ App completed. View run at https://modal.com/apps/evilret/main/ap-AeWY5wl0TIdClFKywjW20W
# '<|begin_of_text|>Life is a mystery, everyone must stand alone, I hear you call my name,'

# %%
import modal
from pricer_ephemeral import app, price

# %%
with modal.enable_output():
    with app.run():
        result=price.remote("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
result
# Out:
# Output()
# ✓ Initialized. View run at https://modal.com/apps/evilret/main/ap-Wxe6RiaUPQlcljQ9RISVFP
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# Building image im-2tnqP76uWLJSkyxCywrXI8
# => Step 0: FROM base
# => Step 1: RUN python -m pip install accelerate bitsandbytes peft torch transformers
# Looking in indexes: http://pypi-mirror.modal.local:5555/simple
# Collecting accelerate
#   Downloading http://pypi-mirror.modal.local:5555/simple/accelerate/accelerate-1.2.1-py3-none-any.whl.metadata (19 kB)
# Collecting bitsandbytes
#   Downloading http://pypi-mirror.modal.local:5555/simple/bitsandbytes/bitsandbytes-0.45.0-py3-none-manylinux_2_24_x86_64.whl.metadata (2.9 kB)
# Collecting peft
#   Downloading http://pypi-mirror.modal.local:5555/simple/peft/peft-0.14.0-py3-none-any.whl.metadata (13 kB)
# Collecting torch
#   Downloading http://pypi-mirror.modal.local:5555/simple/torch/torch-2.5.1-cp311-cp311-manylinux1_x86_64.whl.metadata (28 kB)
# Collecting transformers
#   Downloading http://pypi-mirror.modal.local:5555/simple/transformers/transformers-4.47.0-py3-none-any.whl.metadata (43 kB)
# Collecting numpy<3.0.0,>=1.17 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/numpy/numpy-2.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting packaging>=20.0 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/packaging/packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting psutil (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/psutil/psutil-6.1.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting pyyaml (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/pyyaml/PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting huggingface-hub>=0.21.0 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/huggingface-hub/huggingface_hub-0.27.0-py3-none-any.whl.metadata (13 kB)
# Collecting safetensors>=0.4.3 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/safetensors/safetensors-0.4.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: typing_extensions>=4.8.0 in /usr/local/lib/python3.11/site-packages (from bitsandbytes) (4.12.2)
# Collecting tqdm (from peft)
#   Downloading http://pypi-mirror.modal.local:5555/simple/tqdm/tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting filelock (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/filelock/filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting networkx (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/networkx/networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/jinja2/jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting fsspec (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/fsspec/fsspec-2024.10.0-py3-none-any.whl.metadata (11 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-nvrtc-cu12/nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-runtime-cu12/nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-cupti-cu12/nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cublas-cu12/nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufft-cu12/nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-curand-cu12/nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusolver-cu12/nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparse-cu12/nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nccl-cu12/nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvtx-cu12/nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvjitlink-cu12/nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.1.0 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/triton/triton-3.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# Collecting sympy==1.13.1 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/sympy/sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/mpmath/mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting regex!=2019.12.17 (from transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/regex/regex-2024.11.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
# Collecting requests (from transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/requests/requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting tokenizers<0.22,>=0.21 (from transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/tokenizers/tokenizers-0.21.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/markupsafe/MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting charset-normalizer<4,>=2 (from requests->transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/charset-normalizer/charset_normalizer-3.4.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (34 kB)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/site-packages (from requests->transformers) (3.10)
# Collecting urllib3<3,>=1.21.1 (from requests->transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/urllib3/urllib3-2.2.3-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/site-packages (from requests->transformers) (2024.8.30)
# Downloading http://pypi-mirror.modal.local:5555/simple/accelerate/accelerate-1.2.1-py3-none-any.whl (336 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/bitsandbytes/bitsandbytes-0.45.0-py3-none-manylinux_2_24_x86_64.whl (69.1 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 MB 231.5 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/peft/peft-0.14.0-py3-none-any.whl (374 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/torch/torch-2.5.1-cp311-cp311-manylinux1_x86_64.whl (906.5 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.5/906.5 MB 424.1 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cublas-cu12/nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 503.3 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-cupti-cu12/nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 442.9 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-nvrtc-cu12/nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 506.7 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-runtime-cu12/nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 768.0 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 604.6 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufft-cu12/nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 606.1 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-curand-cu12/nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 560.1 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusolver-cu12/nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 593.5 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparse-cu12/nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 549.0 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nccl-cu12/nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 568.3 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvjitlink-cu12/nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 552.2 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvtx-cu12/nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/sympy/sympy-1.13.1-py3-none-any.whl (6.2 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 522.0 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/triton/triton-3.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (209.5 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 544.7 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/transformers/transformers-4.47.0-py3-none-any.whl (10.1 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 520.7 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/huggingface-hub/huggingface_hub-0.27.0-py3-none-any.whl (450 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/fsspec/fsspec-2024.10.0-py3-none-any.whl (179 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/numpy/numpy-2.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 497.4 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/packaging/packaging-24.2-py3-none-any.whl (65 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/pyyaml/PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (762 kB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 763.0/763.0 kB 1.3 GB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/regex/regex-2024.11.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (792 kB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 792.7/792.7 kB 427.4 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/safetensors/safetensors-0.4.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (435 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/tokenizers/tokenizers-0.21.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 603.4 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/tqdm/tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/filelock/filelock-3.16.1-py3-none-any.whl (16 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/jinja2/jinja2-3.1.4-py3-none-any.whl (133 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/networkx/networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 763.7 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/psutil/psutil-6.1.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (287 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/requests/requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/charset-normalizer/charset_normalizer-3.4.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/markupsafe/MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/mpmath/mpmath-1.3.0-py3-none-any.whl (536 kB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 860.0 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/urllib3/urllib3-2.2.3-py3-none-any.whl (126 kB)
# Installing collected packages: mpmath, urllib3, tqdm, sympy, safetensors, regex, pyyaml, psutil, packaging, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, MarkupSafe, fsspec, filelock, charset-normalizer, triton, requests, nvidia-cusparse-cu12, nvidia-cudnn-cu12, jinja2, nvidia-cusolver-cu12, huggingface-hub, torch, tokenizers, transformers, bitsandbytes, accelerate, peft
# Successfully installed MarkupSafe-3.0.2 accelerate-1.2.1 bitsandbytes-0.45.0 charset-normalizer-3.4.0 filelock-3.16.1 fsspec-2024.10.0 huggingface-hub-0.27.0 jinja2-3.1.4 mpmath-1.3.0 networkx-3.4.2 numpy-2.2.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.4.127 packaging-24.2 peft-0.14.0 psutil-6.1.0 pyyaml-6.0.2 regex-2024.11.6 requests-2.32.3 safetensors-0.4.5 sympy-1.13.1 tokenizers-0.21.0 torch-2.5.1 tqdm-4.67.1 transformers-4.47.0 triton-3.1.0 urllib3-2.2.3
# Saving image...
# Image saved, took 2.93s
# Built image im-2tnqP76uWLJSkyxCywrXI8 in 68.01s
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ✓ Created objects.
# ├── 🔨 Created mount /Users/eevv/focus/llm_engineering/week8/pricer_ephemeral.py
# ├── 🔨 Created mount PythonPackage:hello
# ├── 🔨 Created mount PythonPackage:llama
# └── 🔨 Created function price.
# Output()
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# [Thread-5 (thread_inner)] 2024-12-16T23:46:40-0800 Loop attempt for _run_app.<locals>.heartbeat failed
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/llms/lib/python3.11/site-packages/modal/_utils/async_utils.py", line 195, in loop_coro
#     await asyncio.wait_for(async_f(), timeout=timeout)
#   File "/opt/anaconda3/envs/llms/lib/python3.11/asyncio/tasks.py", line 489, in wait_for
#     return fut.result()
#            ^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/llms/lib/python3.11/site-packages/modal/runner.py", line 56, in _heartbeat
#     await retry_transient_errors(client.stub.AppHeartbeat, request, attempt_timeout=HEARTBEAT_TIMEOUT)
#   File "/opt/anaconda3/envs/llms/lib/python3.11/site-packages/modal/_utils/grpc_utils.py", line 184, in retry_transient_errors
#     raise exc
#   File "/opt/anaconda3/envs/llms/lib/python3.11/site-packages/modal/_utils/grpc_utils.py", line 178, in retry_transient_errors
#     return await fn(*args, metadata=metadata, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/llms/lib/python3.11/site-packages/modal/client.py", line 396, in __call__
#     return await self.client._call_unary(self._wrapped_method_name, req, timeout=timeout, metadata=metadata)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/llms/lib/python3.11/site-packages/modal/client.py", line 338, in _call_unary
#     return await self._call_safely(coro, grpclib_method.name)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/llms/lib/python3.11/site-packages/modal/client.py", line 296, in _call_safely
#     return await request_task
#            ^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/llms/lib/python3.11/site-packages/grpclib/client.py", line 904, in __call__
#     reply = await stream.recv_message()
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/llms/lib/python3.11/site-packages/grpclib/client.py", line 425, in recv_message
#     await self.recv_initial_metadata()
#   File "/opt/anaconda3/envs/llms/lib/python3.11/site-packages/grpclib/client.py", line 393, in recv_initial_metadata
#     self._raise_for_grpc_status(status, message, details)
#   File "/opt/anaconda3/envs/llms/lib/python3.11/site-packages/grpclib/client.py", line 345, in _raise_for_grpc_status
#     raise GRPCError(status, message, details)
# grpclib.exceptions.GRPCError: (<Status.FAILED_PRECONDITION: 9>, 'App state is APP_STATE_STOPPED', None)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Stopping app - local client disconnected. Use `modal run --detach` to keep apps running even if your local client disconnects.
# Downloading shards:   0%|          | 0/4 [07:07<?, ?it/s]
# Runner terminated.
# ---------------------------------------------------------------------------
# RemoteError                               Traceback (most recent call last)
# Cell In[8], line 3
#       1 with modal.enable_output():
#       2     with app.run():
# ----> 3         result=price.remote("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
#       4 result
#
# File /opt/anaconda3/envs/llms/lib/python3.11/site-packages/synchronicity/synchronizer.py:594, in Synchronizer._wrap_proxy_method.<locals>.proxy_method(self, *args, **kwargs)
#     592 instance = self.__dict__[synchronizer_self._original_attr]
#     593 try:
# --> 594     return wrapped_method(instance, *args, **kwargs)
#     595 except UserCodeException as uc_exc:
#     596     uc_exc.exc.__suppress_context__ = True
#
# File /opt/anaconda3/envs/llms/lib/python3.11/site-packages/synchronicity/combined_types.py:29, in FunctionWithAio.__call__(self, *args, **kwargs)
#      27 except UserCodeException as uc_exc:
#      28     uc_exc.exc.__suppress_context__ = True
# ---> 29     raise uc_exc.exc
#
# File /opt/anaconda3/envs/llms/lib/python3.11/site-packages/modal/object.py:253, in live_method.<locals>.wrapped(self, *args, **kwargs)
#     250 @wraps(method)
#     251 async def wrapped(self, *args, **kwargs):
#     252     await self.resolve()
# --> 253     return await method(self, *args, **kwargs)
#
# File /opt/anaconda3/envs/llms/lib/python3.11/site-packages/modal/functions.py:1296, in _Function.remote(self, *args, **kwargs)
#    1291 if self._is_generator:
#    1292     raise InvalidError(
#    1293         "A generator function cannot be called with `.remote(...)`. Use `.remote_gen(...)` instead."
#    1294     )
# -> 1296 return await self._call_function(args, kwargs)
#
# File /opt/anaconda3/envs/llms/lib/python3.11/site-packages/modal/functions.py:1250, in _Function._call_function(self, args, kwargs)
#    1241     function_call_invocation_type = api_pb2.FUNCTION_CALL_INVOCATION_TYPE_SYNC_LEGACY
#    1242 invocation = await _Invocation.create(
#    1243     self,
#    1244     args,
#    (...)
#    1247     function_call_invocation_type=function_call_invocation_type,
#    1248 )
# -> 1250 return await invocation.run_function()
#
# File /opt/anaconda3/envs/llms/lib/python3.11/site-packages/modal/functions.py:243, in _Invocation.run_function(self)
#     236 ctx = self._retry_context
#     237 if (
#     238     not ctx
#     239     or not ctx.retry_policy
#     240     or ctx.retry_policy.retries == 0
#     241     or ctx.function_call_invocation_type != api_pb2.FUNCTION_CALL_INVOCATION_TYPE_SYNC
#     242 ):
# --> 243     return await self._get_single_output()
#     245 # User errors including timeouts are managed by the user specified retry policy.
#     246 user_retry_manager = RetryManager(ctx.retry_policy)
#
# File /opt/anaconda3/envs/llms/lib/python3.11/site-packages/modal/functions.py:232, in _Invocation._get_single_output(self)
#     227 async def _get_single_output(self) -> Any:
#     228     # waits indefinitely for a single result for the function, and clear the outputs buffer after
#     229     item: api_pb2.FunctionGetOutputsItem = (
#     230         await self.pop_function_call_outputs(timeout=None, clear_on_success=True)
#     231     ).outputs[0]
# --> 232     return await _process_result(item.result, item.data_format, self.stub, self.client)
#
# File /opt/anaconda3/envs/llms/lib/python3.11/site-packages/modal/_utils/function_utils.py:485, in _process_result(result, data_format, stub, client)
#     483         uc_exc = UserCodeException(exc_with_hints(exc))
#     484         raise uc_exc
# --> 485     raise RemoteError(result.exception)
#     487 try:
#     488     return deserialize_data_format(data, data_format, client)
#
# RemoteError:

# %% [markdown]
# ## Transitioning From Ephemeral Apps to Deployed Apps
#
# From a command line, `modal deploy xxx` will deploy your code as a Deployed App
#
# This is how you could package your AI service behind an API to be used in a Production System.
#
# You can also build REST endpoints easily, although we won't cover that as we'll be calling direct from Python.
#
# ## Important note:
#
# On the next line, I call `modal deploy` from within Jupyter lab; I've heard that on some versions of Windows this gives a strange unicode error because modal prints emojis to the output which can't be displayed. If that happens to you, simply use an Anaconda Prompt window or a Powershell instead, with your environment activated, and type `modal deploy pricer_service` there. Follow the same approach the next time we do !modal deploy too.

# %%
# !modal deploy pricer_service
# Out:
# ⠸ Creating objects.....
# └── ⠋ Creating mount /Users/eevv/focus/llm_engineering/week8/pricer_service.py:
# ⠦ Creating objects...
# └── ⠸ Creating mount /Users/eevv/focus/llm_engineering/week8/pricer_service.py:
# ⠏ Creating objects...
# ├── 🔨 Created mount /Users/eevv/focus/llm_engineering/week8/pricer_service.py
# ⠋ Creating objects...ice...
# ├── 🔨 Created mount /Users/eevv/focus/llm_engineering/week8/pricer_service.py
# └── 🔨 Created function price.
# ✓ Created objects.
# ├── 🔨 Created mount /Users/eevv/focus/llm_engineering/week8/pricer_service.py
# └── 🔨 Created function price.
# ✓ App deployed in 1.270s! 🎉
#
# View Deployment: https://modal.com/apps/evilret/main/deployed/pricer-service

# %%
pricer = modal.Function.lookup("pricer-service", "price")

# %%
pricer.remote("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
# Out:
# 133.0

# %%
# You can also run "modal deploy pricer_service2" at the command line in an activated environment
# !modal deploy pricer_service2
# Out:
# ⠸ Creating objects.....
# └── ⠋ Creating mount /Users/eevv/focus/llm_engineering/week8/pricer_service2.py:
# ⠦ Creating objects...
# ⠏ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# Building image im-I9010H7Cjy2vFYIj7Qq1hU_engineering/week8/pricer_service2.py
# ⠋ Creating objects...
# ⠹ Creating objects...nt /Users/eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠦ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠏ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# 0m🔨 Created mount /Users/eevv/focus/llm_engineering/week8/pricer_service2.py
# => Step 0: FROM base
# ⠋ Creating objects...
# ─ 🔨 Created mount /Users/eevv/focus/llm_engineering/week8/pricer_service2.py
# => Step 1: RUN python -m pip install accelerate bitsandbytes huggingface peft torch transformers
# ⠋ Creating objects...
# ⠹ Creating objects...nt /Users/eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠦ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠏ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠹ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# Looking in indexes: http://pypi-mirror.modal.local:5555/simplecer_service2.py
# ⠹ Creating objects...
# Collecting accelerate mount /Users/eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠸ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/accelerate/accelerate-1.2.1-py3-none-any.whl.metadata (19 kB)
# ⠸ Creating objects...
# Collecting bitsandbytesount /Users/eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠼ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/bitsandbytes/bitsandbytes-0.45.0-py3-none-manylinux_2_24_x86_64.whl.metadata (2.9 kB)
# ⠼ Creating objects...
# Collecting huggingfacemount /Users/eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠼ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/huggingface/huggingface-0.0.1-py3-none-any.whl.metadata (2.9 kB)
# ⠼ Creating objects...
# Collecting peftreated mount /Users/eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠼ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/peft/peft-0.14.0-py3-none-any.whl.metadata (13 kB)
# ⠼ Creating objects...
# Collecting torcheated mount /Users/eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠴ Creating objects...
# ⠴ Creating objects...nt /Users/eevv/focus/llm_engineering/week8/pricer_service2.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/torch/torch-2.5.1-cp311-cp311-manylinux1_x86_64.whl.metadata (28 kB)
# ⠴ Creating objects...
# Collecting transformersount /Users/eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠦ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/transformers/transformers-4.47.1-py3-none-any.whl.metadata (44 kB)
# ⠦ Creating objects...
# ⠏ Creating objects...nt /Users/eevv/focus/llm_engineering/week8/pricer_service2.py
# Collecting numpy<3.0.0,>=1.17 (from accelerate)ering/week8/pricer_service2.py
# ⠙ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/numpy/numpy-2.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# ⠙ Creating objects...
# Collecting packaging>=20.0 (from accelerate)s/llm_engineering/week8/pricer_service2.py
# ⠙ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/packaging/packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# ⠙ Creating objects...
# ⠹ Creating objects...nt /Users/eevv/focus/llm_engineering/week8/pricer_service2.py
# Collecting psutil (from accelerate)s/llm_engineering/week8/pricer_service2.py
# ⠸ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/psutil/psutil-6.1.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# ⠸ Creating objects...
# Collecting pyyaml (from accelerate)eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠸ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/pyyaml/PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# ⠸ Creating objects...
# Collecting huggingface-hub>=0.21.0 (from accelerate)gineering/week8/pricer_service2.py
# ⠸ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/huggingface-hub/huggingface_hub-0.27.0-py3-none-any.whl.metadata (13 kB)
# ⠸ Creating objects...
# Collecting safetensors>=0.4.3 (from accelerate)lm_engineering/week8/pricer_service2.py
# ⠴ Creating objects...
# ⠴ Creating objects...nt /Users/eevv/focus/llm_engineering/week8/pricer_service2.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/safetensors/safetensors-0.4.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# ⠦ Creating objects...
# Requirement already satisfied: typing_extensions>=4.8.0 in /usr/local/lib/python3.11/site-packages (from bitsandbytes) (4.12.2)
# ⠦ Creating objects...
# Collecting tqdm (from peft) /Users/eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠦ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/tqdm/tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# ⠦ Creating objects...
# Collecting filelock (from torch)rs/eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠧ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/filelock/filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# ⠧ Creating objects...
# Collecting networkx (from torch)rs/eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠧ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/networkx/networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# ⠧ Creating objects...
# Collecting jinja2 (from torch)sers/eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠧ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/jinja2/jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# ⠧ Creating objects...
# Collecting fsspec (from torch)sers/eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠇ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/fsspec/fsspec-2024.10.0-py3-none-any.whl.metadata (11 kB)
# ⠇ Creating objects...
# ⠇ Creating objects...nt /Users/eevv/focus/llm_engineering/week8/pricer_service2.py
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)k8/pricer_service2.py
# ⠇ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-nvrtc-cu12/nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ⠇ Creating objects...
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)ing/week8/pricer_service2.py
# ⠇ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-runtime-cu12/nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ⠇ Creating objects...
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)ering/week8/pricer_service2.py
# ⠇ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-cupti-cu12/nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# ⠏ Creating objects...
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)ngineering/week8/pricer_service2.py
# ⠏ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# ⠏ Creating objects...
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)gineering/week8/pricer_service2.py
# ⠏ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cublas-cu12/nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ⠏ Creating objects...
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)ngineering/week8/pricer_service2.py
# ⠏ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufft-cu12/nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ⠏ Creating objects...
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)neering/week8/pricer_service2.py
# ⠏ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-curand-cu12/nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ⠏ Creating objects...
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)neering/week8/pricer_service2.py
# ⠏ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusolver-cu12/nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# ⠏ Creating objects...
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)ering/week8/pricer_service2.py
# ⠏ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparse-cu12/nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# ⠋ Creating objects...
# Collecting nvidia-nccl-cu12==2.21.5 (from torch)m_engineering/week8/pricer_service2.py
# ⠋ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nccl-cu12/nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# ⠋ Creating objects...
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch)engineering/week8/pricer_service2.py
# ⠋ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvtx-cu12/nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# ⠋ Creating objects...
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)eering/week8/pricer_service2.py
# ⠋ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvjitlink-cu12/nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ⠋ Creating objects...
# Collecting triton==3.1.0 (from torch)vv/focus/llm_engineering/week8/pricer_service2.py
# ⠙ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/triton/triton-3.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# ⠙ Creating objects...
# Collecting sympy==1.13.1 (from torch)vv/focus/llm_engineering/week8/pricer_service2.py
# ⠙ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/sympy/sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# ⠙ Creating objects...
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch)ring/week8/pricer_service2.py
# ⠙ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/mpmath/mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# ⠙ Creating objects...
# ⠹ Creating objects...nt /Users/eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠴ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# Collecting regex!=2019.12.17 (from transformers)ring/week8/pricer_service2.py
# ⠇ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/regex/regex-2024.11.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
# ⠇ Creating objects...
# Collecting requests (from transformers)/focus/llm_engineering/week8/pricer_service2.py
# ⠇ Creating objects...
# ⠇ Creating objects...nt /Users/eevv/focus/llm_engineering/week8/pricer_service2.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/requests/requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# ⠇ Creating objects...
# Collecting tokenizers<0.22,>=0.21 (from transformers)ineering/week8/pricer_service2.py
# ⠋ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/tokenizers/tokenizers-0.21.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# ⠙ Creating objects...
# ⠙ Creating objects...nt /Users/eevv/focus/llm_engineering/week8/pricer_service2.py
# Collecting MarkupSafe>=2.0 (from jinja2->torch)ering/week8/pricer_service2.py
# ⠹ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/markupsafe/MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# ⠹ Creating objects...
# Collecting charset-normalizer<4,>=2 (from requests->transformers)k8/pricer_service2.py
# ⠸ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/charset-normalizer/charset_normalizer-3.4.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (34 kB)
# ⠼ Creating objects...
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/site-packages (from requests->transformers) (3.10)
# ⠼ Creating objects...
# ⠼ Creating objects...nt /Users/eevv/focus/llm_engineering/week8/pricer_service2.py
# Collecting urllib3<3,>=1.21.1 (from requests->transformers)pricer_service2.py
# ⠼ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/urllib3/urllib3-2.2.3-py3-none-any.whl.metadata (6.5 kB)
# ⠼ Creating objects...
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/site-packages (from requests->transformers) (2024.8.30)
# ⠴ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/accelerate/accelerate-1.2.1-py3-none-any.whl (336 kB)
# ⠴ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/bitsandbytes/bitsandbytes-0.45.0-py3-none-manylinux_2_24_x86_64.whl (69.1 MB)
# ⠴ Creating objects...
# ⠇ Creating objects...nt /Users/eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠇ Creating objects...m_engineering/week8/pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 MB 254.9 MB/s eta 0:00:00ice2.py
# ⠇ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/huggingface/huggingface-0.0.1-py3-none-any.whl (2.5 kB)
# ⠇ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/peft/peft-0.14.0-py3-none-any.whl (374 kB)
# ⠇ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/torch/torch-2.5.1-cp311-cp311-manylinux1_x86_64.whl (906.5 MB)
# ⠇ Creating objects...
# ⠙ Creating objects...nt /Users/eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠼ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠧ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠙ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠼ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠧ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠋ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠼ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠧ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠋ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠸ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠧ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠋ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠹ Creating objects...m_engineering/week8/pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.5/906.5 MB 264.6 MB/s eta 0:00:00ce2.py
# ⠸ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cublas-cu12/nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
# ⠸ Creating objects...
# ⠸ Creating objects...nt /Users/eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠦ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠋ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠸ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠦ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠏ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠋ Creating objects...m_engineering/week8/pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 261.8 MB/s eta 0:00:00ce2.py
# ⠋ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-cupti-cu12/nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
# ⠋ Creating objects...
# ⠹ Creating objects.../focus/llm_engineering/week8/pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 186.3 MB/s eta 0:00:00ice2.py
# ⠹ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-nvrtc-cu12/nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
# ⠹ Creating objects...
# ⠹ Creating objects.../focus/llm_engineering/week8/pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 247.2 MB/s eta 0:00:00ice2.py
# ⠹ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-runtime-cu12/nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
# ⠹ Creating objects...
# ⠹ Creating objects.../focus/llm_engineering/week8/pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 324.3 MB/s eta 0:00:00ce2.py
# ⠹ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
# ⠹ Creating objects...
# ⠸ Creating objects...nt /Users/eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠦ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠏ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠹ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠦ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠏ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠹ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠴ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠧ Creating objects...m_engineering/week8/pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 278.1 MB/s eta 0:00:00ce2.py
# ⠇ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufft-cu12/nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
# ⠇ Creating objects...
# ⠇ Creating objects...nt /Users/eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠹ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠴ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠇ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠇ Creating objects...m_engineering/week8/pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 234.5 MB/s eta 0:00:00ce2.py
# ⠙ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-curand-cu12/nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
# ⠙ Creating objects...
# ⠙ Creating objects.../focus/llm_engineering/week8/pricer_service2.py
# ⠙ Creating objects...nt /Users/eevv/focus/llm_engineering/week8/pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 273.7 MB/s eta 0:00:00
# ⠸ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusolver-cu12/nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
# ⠸ Creating objects...
# ⠴ Creating objects...nt /Users/eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠧ Creating objects...m_engineering/week8/pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 310.8 MB/s eta 0:00:00ce2.py
# ⠧ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparse-cu12/nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
# ⠧ Creating objects...
# ⠇ Creating objects...nt /Users/eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠙ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠼ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠦ Creating objects...m_engineering/week8/pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 335.3 MB/s eta 0:00:00ce2.py
# ⠦ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nccl-cu12/nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
# ⠦ Creating objects...
# ⠇ Creating objects...nt /Users/eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠙ Creating objects...m_engineering/week8/pricer_service2.py
# ⠙ Creating objects...nt /Users/eevv/focus/llm_engineering/week8/pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 358.5 MB/s eta 0:00:00
# ⠙ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvjitlink-cu12/nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# ⠙ Creating objects...
# ⠹ Creating objects.../focus/llm_engineering/week8/pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 308.7 MB/s eta 0:00:00ice2.py
# ⠹ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvtx-cu12/nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
# ⠹ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/sympy/sympy-1.13.1-py3-none-any.whl (6.2 MB)
# ⠹ Creating objects...
# ⠸ Creating objects.../focus/llm_engineering/week8/pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 339.8 MB/s eta 0:00:00rvice2.py
# ⠸ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/triton/triton-3.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (209.5 MB)
# ⠸ Creating objects...
# ⠼ Creating objects...nt /Users/eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠧ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠙ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠼ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠴ Creating objects...m_engineering/week8/pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 214.7 MB/s eta 0:00:00ce2.py
# ⠴ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/transformers/transformers-4.47.1-py3-none-any.whl (10.1 MB)
# ⠴ Creating objects...
# ⠴ Creating objects.../focus/llm_engineering/week8/pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 318.3 MB/s eta 0:00:00ice2.py
# ⠴ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/huggingface-hub/huggingface_hub-0.27.0-py3-none-any.whl (450 kB)
# ⠴ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/fsspec/fsspec-2024.10.0-py3-none-any.whl (179 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/numpy/numpy-2.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
# ⠦ Creating objects...
# ⠦ Creating objects.../focus/llm_engineering/week8/pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 395.6 MB/s eta 0:00:00ice2.py
# ⠦ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/packaging/packaging-24.2-py3-none-any.whl (65 kB)
# ⠦ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/pyyaml/PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (762 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 763.0/763.0 kB 352.5 MB/s eta 0:00:00
# ⠦ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/regex/regex-2024.11.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (792 kB)
# ⠦ Creating objects...
# ⠦ Creating objects.../focus/llm_engineering/week8/pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 792.7/792.7 kB 309.7 MB/s eta 0:00:00ce2.py
# ⠦ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/safetensors/safetensors-0.4.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (435 kB)
# ⠦ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/tokenizers/tokenizers-0.21.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
# ⠦ Creating objects...
# ⠦ Creating objects.../focus/llm_engineering/week8/pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 199.6 MB/s eta 0:00:00rvice2.py
# ⠦ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/tqdm/tqdm-4.67.1-py3-none-any.whl (78 kB)
# ⠦ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/filelock/filelock-3.16.1-py3-none-any.whl (16 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/jinja2/jinja2-3.1.4-py3-none-any.whl (133 kB)
# ⠦ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/networkx/networkx-3.4.2-py3-none-any.whl (1.7 MB)
# ⠧ Creating objects...
# ⠧ Creating objects.../focus/llm_engineering/week8/pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 357.9 MB/s eta 0:00:00rvice2.py
# ⠧ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/psutil/psutil-6.1.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (287 kB)
# ⠧ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/requests/requests-2.32.3-py3-none-any.whl (64 kB)
# ⠧ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/charset-normalizer/charset_normalizer-3.4.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
# ⠧ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/markupsafe/MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23 kB)
# ⠧ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/mpmath/mpmath-1.3.0-py3-none-any.whl (536 kB)
# ⠧ Creating objects...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 350.8 MB/s eta 0:00:00ce2.py
# ⠧ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/urllib3/urllib3-2.2.3-py3-none-any.whl (126 kB)
# ⠧ Creating objects...
# ⠧ Creating objects...nt /Users/eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠋ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠸ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠧ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠋ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠸ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠦ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠋ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠸ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠦ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠏ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠹ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠦ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠏ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠹ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠦ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠏ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠹ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠴ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠇ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠹ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠴ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠇ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠙ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠴ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠇ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠙ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠼ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠇ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠙ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# Installing collected packages: mpmath, huggingface, urllib3, tqdm, sympy, safetensors, regex, pyyaml, psutil, packaging, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, MarkupSafe, fsspec, filelock, charset-normalizer, triton, requests, nvidia-cusparse-cu12, nvidia-cudnn-cu12, jinja2, nvidia-cusolver-cu12, huggingface-hub, torch, tokenizers, transformers, bitsandbytes, accelerate, peft
# ⠹ Creating objects...
# ⠼ Creating objects...nt /Users/eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠧ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠋ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠼ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠧ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠋ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠸ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠧ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠋ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠸ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠦ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠋ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠸ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠦ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠏ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠸ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠦ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠏ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠹ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠦ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠏ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠹ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠴ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠏ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠹ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠴ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠇ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠹ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠴ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠇ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠙ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠴ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠇ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠙ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠼ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠇ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠙ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠼ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠧ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠙ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠼ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠧ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠋ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠼ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠧ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠋ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠸ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠧ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠋ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠸ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠦ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠋ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠸ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠦ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠏ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠹ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠦ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠏ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠹ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠴ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠇ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠹ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠴ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠇ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠙ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠴ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠇ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠙ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠼ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠧ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠙ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠼ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠧ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠋ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠼ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠧ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠋ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠸ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠧ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠋ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠸ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠦ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# ⠧ Creating objects.../eevv/focus/llm_engineering/week8/pricer_service2.py
# └── 🔨 Created mount /Users/eevv/focus/llm_engineering/week8/pricer_service2.py
# ╭─ Error ──────────────────────────────────────────────────────────────────────╮
# │ 'NoneType' object has no attribute '_write_appdata'                          │
# ╰──────────────────────────────────────────────────────────────────────────────╯

# %%
Pricer = modal.Cls.lookup("pricer-service", "Pricer")
pricer = Pricer()
reply = pricer.price.remote("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
print(reply)

# %% [markdown]
# # Optional: Keeping Modal warm
#
# ## A way to improve the speed of the Modal pricer service
#
# A student mentioned to me that he was concerned by how slow Modal seems to be. The reason is that Modal puts our service to sleep if we don't use it, and then it takes 2.5 minutes to spin back up.
#
# I've added a utility called `keep_warm.py` that will keep our Modal warm by pinging it every 30 seconds.
#
# To use the utliity, bring up a new Terminal (Mac) or Anaconda prompt (Windows), ensure the environment is activated with `conda activate llms`
#
# Then run: `python keep_warm.py` from within the week8 drectory.
#
# Remember to press ctrl+C or exit the window when you no longer need Modal running.

# %% [markdown]
# ## And now introducing our Agent class

# %%
from agents.specialist_agent import SpecialistAgent

# %%
agent = SpecialistAgent()
agent.price("iPad Pro 2nd generation")
